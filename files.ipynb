# %%
import json

file = open("sw_templates.json", 'r')
data = json.load(file)
data
# Out:
# {'access': ['switchport mode access',
#   'switchport access vlan',
#   'switchport nonegotiate',
#   'spanning-tree portfast',
#   'spanning-tree bpduguard enable'],
#  'trunk': ['switchport trunk encapsulation dot1q',
#   'switchport mode trunk',
#   'switchport trunk native vlan 999',
#   'switchport trunk allowed vlan']}

# %%
import pyarrow.parquet as pq

table = pq.read_table("Shuffled.parquet")
df = table.to_pandas()
df
# Out:
#           brand    model fuel_type  mileage  year owner_type  accidents  \
# 968       Lexus       GX       Gas    51271  2001      First          2
# 848     Porsche    Macan    Hybrid    20254  2018      First          4
# 974       Lexus       GX    Hybrid    55448  2009      First          0
# 91         Audi       A6    Diesel   197300  2011      Third          2
# 808       Volvo     XC40    Hybrid    15916  2022      First          3
# ..          ...      ...       ...      ...   ...        ...        ...
# 772       Volvo     XC60    Hybrid    61570  2000      Third          0
# 501  Volkswagen    Jetta  Electric   171319  2015      First          0
# 165        Ford  Mustang    Hybrid   100259  2013      First          0
# 680        Jeep  Compass       Gas    49482  2010     Second          4
# 864     Porsche   Taycan       Gas   197958  2021     Second          3
#
#            color transmission       price  car_age
# 968  Transparent    Automatic   361263.41       22
# ...
